# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuj57/Week-7/blob/main/Week_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image 
import numpy as np  


img1 = Image.open("/content/Image.jpg")
print(type(img1))
print(img1.mode) 
img = np.asarray(img1)
print(type(img1))
img
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# RGB
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# array([[[ 47,  93, 106],
#         [ 45,  91, 104],
#         [ 40,  88, 100],
#         ...,
#         [ 78, 150, 174],
#         [ 76, 148, 172],
#         [ 75, 147, 171]],
#
#        [[ 45,  91, 104],
#         [ 43,  89, 102],
#         [ 39,  87,  99],
#         ...,
#         [ 78, 150, 174],
#         [ 76, 148, 172],
#         [ 74, 146, 170]],
#
#        [[ 41,  89, 101],
#         [ 40,  88, 100],
#         [ 38,  86,  98],
#         ...,
#         [ 77, 149, 173],
#         [ 75, 147, 171],
#         [ 74, 146, 170]],
#
#        ...,
#
#        [[ 28, 196, 196],
#         [ 29, 197, 197],
#         [ 32, 198, 198],
#         ...,
#         [120, 217, 234],
#         [131, 226, 244],
#         [139, 232, 250]],
#
#        [[ 28, 198, 197],
#         [ 28, 198, 197],
#         [ 32, 198, 198],
#         ...,
#         [120, 215, 233],
#         [131, 224, 242],
# ...

# %%
print("Shape of the image =",img.shape)
# Out:
# Shape of the image = (224, 224, 3)

# %%
#using matplotlib
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
 
print(type(img1))


print(img.shape)

plt.imshow(img1)
plt.colorbar()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# (224, 224, 3)

# %%
#for second image
img2 = Image.open("/content/Image 1.jpg")
print(type(img2))
print(img2.mode) 
img_2 = np.asarray(img1)
print(type(img1))
print("shape of image 2 is  ",img_2.shape)
plt.imshow(img2)
plt.colorbar()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# RGB
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# shape of image 2 is   (224, 224, 3)

# %%
import cv2 


from google.colab.patches import cv2_imshow

grey_img = cv2.imread("/content/Image 1.jpg", 0)
color_img = cv2.imread("/content/Image 1.jpg", 1)
print(type(grey_img)) 
print(type(color_img)) 
cv2_imshow(grey_img)
cv2_imshow(color_img)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <PIL.Image.Image image mode=L size=279x181 at 0x7F2D9616B990>
# <PIL.Image.Image image mode=RGB size=279x181 at 0x7F2D96106090>

# %%
gray_img2 = cv2.imread("/content/Image 2.jpg", 0)
color_img2 = cv2.imread("/content/Image 2.jpg", 1)
print(type(gray_img2)) 
print(type(color_img2)) 
cv2_imshow(gray_img2)
cv2_imshow(color_img2)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <PIL.Image.Image image mode=L size=275x183 at 0x7F2D8957BCD0>
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F2D8957BD50>

# %%
# BGR to RGB
plt.imshow(cv2.cvtColor(color_img, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(color_img2, cv2.COLOR_BGR2RGB))

# %%
#We can also change color spaces from RGB to HSV..
plt.imshow(cv2.cvtColor(color_img2, cv2.COLOR_BGR2HSV))

# %%
## Negative of the image
[rows,cols] = gray_img2.shape;
neg_img = np.zeros((rows,cols));
for r in range(0, rows-1):
  for c in range(0, cols-1):
    neg_img[r,c] = 255-gray_img2[r,c]; #Calculate negative image
#plt.imshow(neg_img, cmap=plt.cm.gray)
fig = plt.figure()
ax1 = fig.add_subplot(3,3,1)
ax1.imshow(img2)
ax1.set_title('Original image')
ax2 = fig.add_subplot(3,3,2)
ax2.imshow(gray_img2, cmap=plt.cm.gray)
ax2.set_title('Gray image')
ax3 = fig.add_subplot(3,3,3)
ax3.imshow(neg_img)
ax3.set_title('Negative image')
# Out:
# Text(0.5, 1.0, 'Negative image')

# %%
a = 255/(np.log(1 + np.max(gray_img2))) 
log_transformed = c * np.log(1 + gray_img2)
log_transformed1 = np.array(log_transformed, dtype = np.uint8)
plt.imshow(log_transformed1, cmap=plt.cm.gray)
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img2)
ax1.set_title('Original image')
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(gray_img2, cmap=plt.cm.gray)
ax2.set_title('Gray image')
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(neg_img, cmap=plt.cm.gray)
ax3.set_title('Negative')
ax4 = fig.add_subplot(2,2,4)
ax4.imshow(log_transformed1, cmap=plt.cm.gray)
ax4.set_title('Log image')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
# Text(0.5, 1.0, 'Log image')
